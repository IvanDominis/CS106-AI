# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colabgymrender==1.0.2
#   Downloading colabgymrender-1.0.2.tar.gz (1.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (3.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (1.0.3)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (4.7.0.72)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (0.0.8)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.65.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.27.1)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.25.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.4.8)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy->colabgymrender==1.0.2) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (3.4)
# Building wheels for collected packages: colabgymrender
#   Building wheel for colabgymrender (setup.py) ... done
#   Created wheel for colabgymrender: filename=colabgymrender-1.0.2-py3-none-any.whl size=2426 sha256=fc02b1a270849bd47f9b538f7f99bcccdf5929f07b141cade4effb4f62580926
#   Stored in directory: /root/.cache/pip/wheels/54/1d/51/d65a99106096dd07e3be6f08d5d3c2dd5f26ac98f626e5efc9
# Successfully built colabgymrender
# Installing collected packages: colabgymrender
# Successfully installed colabgymrender-1.0.2

# %%
from colabgymrender.recorder import Recorder
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/fx/painting.py:7: DeprecationWarning: Please use `sobel` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import sobel

# %%
env = gym.make('CartPole-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# 13.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t:  87%|████████▋ | 13/15 [00:00<00:00, 123.95it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./video/1687609323.3313575.mp4, 720000 bytes wanted but 0 bytes read,at frame 14/15, at time 0.47/0.47 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
total_reward
# Out:
# 13.0

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 50000
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 5e-4 # learning rate

memory_size = 50000
min_replay_size = 1000
batch_size = 32

target_update_frequency = 1000 # target network update frequency

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 64),
            nn.ReLU(),
            nn.Tanh(),
            # add more layer
            nn.Linear(64,128),
            nn.Tanh(),
            nn.Linear(128, env.action_space.n)
        )

    def forward(self, state):
        return self.network(state)

    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def fill_memory(env):
    memory = deque(maxlen=memory_size)
    state = env.reset()
    for _ in range(min_replay_size):
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        state = next_state
        if done:
            env.reset()

    return memory

# %%
def dqn_training(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork(env)
    target_net = NeuralNetwork(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])

        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)

        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        reward_per_episode += reward

        state = next_state

        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0


        # Take a batch of experiences from the memory
        experiences = random.sample(memory, batch_size)
        states = [ex[0] for ex in experiences]
        actions = [ex[1] for ex in experiences]
        rewards = [ex[2] for ex in experiences]
        dones = [ex[3] for ex in experiences]
        next_states = [ex[4] for ex in experiences]

        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(-1) # (batch_size,) --> (batch_size, 1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(next_states, dtype=torch.float32)

        # Compute targets using the formulation sample = r + gamma * max q(s',a')
        target_q_values = target_net(next_states)
        max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
        targets = rewards + gamma * (1-dones) * max_target_q_values

        # Compute loss
        q_values = q_net(states)

        action_q_values = torch.gather(input=q_values, dim=1, index=actions)
        loss = torch.nn.functional.mse_loss(action_q_values, targets)

        # gradient descent for q-network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # update target network
        if (step+1) % target_update_frequency == 0:
            target_net.load_state_dict(q_net.state_dict())

        # print training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# Episode: 45 Step: 1000 Average reward: 22.22222222222222
# Episode: 94 Step: 2000 Average reward: 21.159574468085108
# Episode: 145 Step: 3000 Average reward: 20.0
# Episode: 191 Step: 4000 Average reward: 20.57
# Episode: 226 Step: 5000 Average reward: 23.67
# Episode: 258 Step: 6000 Average reward: 27.0
# Episode: 281 Step: 7000 Average reward: 31.9
# Episode: 305 Step: 8000 Average reward: 35.87
# Episode: 323 Step: 9000 Average reward: 40.41
# Episode: 335 Step: 10000 Average reward: 47.11
# Episode: 342 Step: 11000 Average reward: 54.38
# Episode: 349 Step: 12000 Average reward: 63.3
# Episode: 354 Step: 13000 Average reward: 70.1
# Episode: 359 Step: 14000 Average reward: 78.01
# Episode: 364 Step: 15000 Average reward: 85.02
# Episode: 369 Step: 16000 Average reward: 93.53
# Episode: 374 Step: 17000 Average reward: 101.9
# Episode: 379 Step: 18000 Average reward: 109.51
# Episode: 384 Step: 19000 Average reward: 117.36
# Episode: 389 Step: 20000 Average reward: 125.33
# Episode: 394 Step: 21000 Average reward: 133.29
# Episode: 399 Step: 22000 Average reward: 140.98
# Episode: 404 Step: 23000 Average reward: 148.87
# Episode: 409 Step: 24000 Average reward: 156.55
# Episode: 414 Step: 25000 Average reward: 164.05
# Episode: 419 Step: 26000 Average reward: 171.41
# Episode: 424 Step: 27000 Average reward: 177.87
# Episode: 429 Step: 28000 Average reward: 183.7
# Episode: 434 Step: 29000 Average reward: 188.92
# Episode: 439 Step: 30000 Average reward: 192.01
# Episode: 444 Step: 31000 Average reward: 196.38
# Episode: 449 Step: 32000 Average reward: 198.05
# Episode: 454 Step: 33000 Average reward: 199.77
# Episode: 459 Step: 34000 Average reward: 199.77
# Episode: 464 Step: 35000 Average reward: 200.0
# Episode: 469 Step: 36000 Average reward: 200.0
# Episode: 474 Step: 37000 Average reward: 200.0
# Episode: 479 Step: 38000 Average reward: 200.0
# Episode: 484 Step: 39000 Average reward: 200.0
# Episode: 489 Step: 40000 Average reward: 200.0
# Episode: 494 Step: 41000 Average reward: 200.0
# Episode: 499 Step: 42000 Average reward: 200.0
# Episode: 504 Step: 43000 Average reward: 200.0
# Episode: 509 Step: 44000 Average reward: 200.0
# Episode: 514 Step: 45000 Average reward: 200.0
# Episode: 519 Step: 46000 Average reward: 200.0
# Episode: 524 Step: 47000 Average reward: 200.0
# Episode: 529 Step: 48000 Average reward: 200.0
# Episode: 534 Step: 49000 Average reward: 200.0
# Episode: 539 Step: 50000 Average reward: 200.0

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# 200.0
# 100%|█████████▉| 201/202 [00:00<00:00, 278.53it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# # Hyperparameter Tuning for MoutainCar-v0

# %%
env = gym.make('MountainCar-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# -200.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 500000 # Increase max_num_steps
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 5e-4 # learning rate

memory_size = 500000
min_replay_size = 1000
batch_size = 32

target_update_frequency = 1000 # target network update frequency

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# Episode: 5 Step: 1000 Average reward: -200.0
# Episode: 10 Step: 2000 Average reward: -200.0
# Episode: 15 Step: 3000 Average reward: -200.0
# Episode: 20 Step: 4000 Average reward: -200.0
# Episode: 25 Step: 5000 Average reward: -200.0
# Episode: 30 Step: 6000 Average reward: -200.0
# Episode: 35 Step: 7000 Average reward: -200.0
# Episode: 40 Step: 8000 Average reward: -200.0
# Episode: 45 Step: 9000 Average reward: -200.0
# Episode: 50 Step: 10000 Average reward: -200.0
# Episode: 55 Step: 11000 Average reward: -200.0
# Episode: 60 Step: 12000 Average reward: -200.0
# Episode: 65 Step: 13000 Average reward: -200.0
# Episode: 70 Step: 14000 Average reward: -200.0
# Episode: 75 Step: 15000 Average reward: -200.0
# Episode: 80 Step: 16000 Average reward: -200.0
# Episode: 85 Step: 17000 Average reward: -200.0
# Episode: 90 Step: 18000 Average reward: -199.4777777777778
# Episode: 95 Step: 19000 Average reward: -198.97894736842105
# Episode: 100 Step: 20000 Average reward: -199.03
# Episode: 105 Step: 21000 Average reward: -198.44
# Episode: 110 Step: 22000 Average reward: -198.21
# Episode: 116 Step: 23000 Average reward: -197.67
# Episode: 121 Step: 24000 Average reward: -197.61
# Episode: 126 Step: 25000 Average reward: -197.61
# Episode: 131 Step: 26000 Average reward: -197.04
# Episode: 136 Step: 27000 Average reward: -196.29
# Episode: 142 Step: 28000 Average reward: -195.92
# Episode: 147 Step: 29000 Average reward: -195.61
# Episode: 152 Step: 30000 Average reward: -195.5
# Episode: 157 Step: 31000 Average reward: -195.5
# Episode: 162 Step: 32000 Average reward: -195.0
# Episode: 167 Step: 33000 Average reward: -195.0
# Episode: 172 Step: 34000 Average reward: -195.0
# Episode: 177 Step: 35000 Average reward: -194.79
# Episode: 182 Step: 36000 Average reward: -194.79
# Episode: 187 Step: 37000 Average reward: -194.77
# Episode: 192 Step: 38000 Average reward: -195.37
# Episode: 197 Step: 39000 Average reward: -195.26
# Episode: 203 Step: 40000 Average reward: -195.0
# Episode: 209 Step: 41000 Average reward: -193.62
# Episode: 214 Step: 42000 Average reward: -193.62
# Episode: 219 Step: 43000 Average reward: -194.22
# Episode: 224 Step: 44000 Average reward: -194.22
# Episode: 229 Step: 45000 Average reward: -194.79
# Episode: 234 Step: 46000 Average reward: -195.54
# Episode: 239 Step: 47000 Average reward: -195.54
# Episode: 244 Step: 48000 Average reward: -196.09
# Episode: 249 Step: 49000 Average reward: -196.33
# Episode: 254 Step: 50000 Average reward: -196.33
# Episode: 259 Step: 51000 Average reward: -196.83
# Episode: 264 Step: 52000 Average reward: -195.97
# Episode: 269 Step: 53000 Average reward: -195.37
# Episode: 275 Step: 54000 Average reward: -194.17
# Episode: 280 Step: 55000 Average reward: -194.17
# Episode: 285 Step: 56000 Average reward: -194.06
# Episode: 291 Step: 57000 Average reward: -192.49
# Episode: 296 Step: 58000 Average reward: -192.02
# Episode: 303 Step: 59000 Average reward: -189.52
# Episode: 308 Step: 60000 Average reward: -190.52
# Episode: 314 Step: 61000 Average reward: -188.99
# Episode: 320 Step: 62000 Average reward: -187.67
# Episode: 325 Step: 63000 Average reward: -187.01
# Episode: 331 Step: 64000 Average reward: -185.44
# Episode: 337 Step: 65000 Average reward: -183.61
# Episode: 342 Step: 66000 Average reward: -182.75
# Episode: 348 Step: 67000 Average reward: -180.85
# Episode: 354 Step: 68000 Average reward: -178.98
# Episode: 360 Step: 69000 Average reward: -176.99
# Episode: 366 Step: 70000 Average reward: -176.23
# Episode: 373 Step: 71000 Average reward: -173.34
# Episode: 379 Step: 72000 Average reward: -171.92
# Episode: 385 Step: 73000 Average reward: -170.53
# Episode: 392 Step: 74000 Average reward: -168.69
# Episode: 397 Step: 75000 Average reward: -168.43
# Episode: 404 Step: 76000 Average reward: -168.19
# Episode: 411 Step: 77000 Average reward: -165.33
# Episode: 418 Step: 78000 Average reward: -163.35
# Episode: 424 Step: 79000 Average reward: -162.48
# Episode: 430 Step: 80000 Average reward: -160.46
# Episode: 437 Step: 81000 Average reward: -159.78
# Episode: 444 Step: 82000 Average reward: -157.67
# Episode: 450 Step: 83000 Average reward: -156.22
# Episode: 456 Step: 84000 Average reward: -156.73
# Episode: 463 Step: 85000 Average reward: -155.1
# Episode: 469 Step: 86000 Average reward: -154.45
# Episode: 475 Step: 87000 Average reward: -156.2
# Episode: 481 Step: 88000 Average reward: -156.91
# Episode: 487 Step: 89000 Average reward: -157.48
# Episode: 493 Step: 90000 Average reward: -157.57
# Episode: 500 Step: 91000 Average reward: -156.83
# Episode: 506 Step: 92000 Average reward: -157.23
# Episode: 512 Step: 93000 Average reward: -158.99
# Episode: 517 Step: 94000 Average reward: -160.62
# Episode: 524 Step: 95000 Average reward: -159.63
# Episode: 531 Step: 96000 Average reward: -159.52
# Episode: 537 Step: 97000 Average reward: -160.2
# Episode: 543 Step: 98000 Average reward: -160.3
# Episode: 550 Step: 99000 Average reward: -161.26
# Episode: 556 Step: 100000 Average reward: -160.24
# Episode: 562 Step: 101000 Average reward: -161.79
# Episode: 570 Step: 102000 Average reward: -159.73
# Episode: 577 Step: 103000 Average reward: -157.03
# Episode: 584 Step: 104000 Average reward: -154.45
# Episode: 591 Step: 105000 Average reward: -153.57
# Episode: 599 Step: 106000 Average reward: -151.74
# Episode: 606 Step: 107000 Average reward: -150.49
# Episode: 612 Step: 108000 Average reward: -149.01
# Episode: 620 Step: 109000 Average reward: -147.01
# Episode: 627 Step: 110000 Average reward: -146.03
# Episode: 636 Step: 111000 Average reward: -141.75
# Episode: 643 Step: 112000 Average reward: -140.55
# Episode: 652 Step: 113000 Average reward: -137.05
# Episode: 658 Step: 114000 Average reward: -136.5
# Episode: 666 Step: 115000 Average reward: -135.22
# Episode: 673 Step: 116000 Average reward: -134.09
# Episode: 679 Step: 117000 Average reward: -136.64
# Episode: 687 Step: 118000 Average reward: -136.37
# Episode: 695 Step: 119000 Average reward: -135.51
# Episode: 702 Step: 120000 Average reward: -134.7
# Episode: 711 Step: 121000 Average reward: -132.68
# Episode: 718 Step: 122000 Average reward: -131.7
# Episode: 725 Step: 123000 Average reward: -133.39
# Episode: 733 Step: 124000 Average reward: -132.39
# Episode: 740 Step: 125000 Average reward: -134.19
# Episode: 746 Step: 126000 Average reward: -135.07
# Episode: 754 Step: 127000 Average reward: -137.05
# Episode: 762 Step: 128000 Average reward: -135.24
# Episode: 768 Step: 129000 Average reward: -136.43
# Episode: 775 Step: 130000 Average reward: -137.19
# Episode: 782 Step: 131000 Average reward: -135.66
# Episode: 789 Step: 132000 Average reward: -136.09
# Episode: 797 Step: 133000 Average reward: -136.3
# Episode: 804 Step: 134000 Average reward: -138.16
# Episode: 812 Step: 135000 Average reward: -138.63
# Episode: 819 Step: 136000 Average reward: -138.84
# Episode: 827 Step: 137000 Average reward: -138.59
# Episode: 833 Step: 138000 Average reward: -139.8
# Episode: 840 Step: 139000 Average reward: -139.01
# Episode: 848 Step: 140000 Average reward: -137.64
# Episode: 856 Step: 141000 Average reward: -136.79
# Episode: 864 Step: 142000 Average reward: -137.06
# Episode: 871 Step: 143000 Average reward: -136.09
# Episode: 878 Step: 144000 Average reward: -136.08
# Episode: 886 Step: 145000 Average reward: -136.0
# Episode: 895 Step: 146000 Average reward: -133.63
# Episode: 903 Step: 147000 Average reward: -131.08
# Episode: 910 Step: 148000 Average reward: -131.96
# Episode: 917 Step: 149000 Average reward: -131.88
# Episode: 924 Step: 150000 Average reward: -133.54
# Episode: 932 Step: 151000 Average reward: -132.27
# Episode: 940 Step: 152000 Average reward: -130.87
# Episode: 946 Step: 153000 Average reward: -131.6
# Episode: 954 Step: 154000 Average reward: -132.44
# Episode: 961 Step: 155000 Average reward: -132.89
# Episode: 969 Step: 156000 Average reward: -133.59
# Episode: 976 Step: 157000 Average reward: -132.48
# Episode: 984 Step: 158000 Average reward: -132.57
# Episode: 992 Step: 159000 Average reward: -132.9
# Episode: 999 Step: 160000 Average reward: -135.04
# Episode: 1007 Step: 161000 Average reward: -133.89
# Episode: 1015 Step: 162000 Average reward: -133.81
# Episode: 1023 Step: 163000 Average reward: -132.43
# Episode: 1031 Step: 164000 Average reward: -131.77
# Episode: 1039 Step: 165000 Average reward: -131.2
# Episode: 1048 Step: 166000 Average reward: -127.68
# Episode: 1056 Step: 167000 Average reward: -127.64
# Episode: 1064 Step: 168000 Average reward: -126.95
# Episode: 1072 Step: 169000 Average reward: -126.9
# Episode: 1080 Step: 170000 Average reward: -126.96
# Episode: 1087 Step: 171000 Average reward: -125.54
# Episode: 1096 Step: 172000 Average reward: -124.51
# Episode: 1105 Step: 173000 Average reward: -123.49
# Episode: 1113 Step: 174000 Average reward: -122.04
# Episode: 1121 Step: 175000 Average reward: -122.99
# Episode: 1129 Step: 176000 Average reward: -122.86
# Episode: 1137 Step: 177000 Average reward: -122.39
# Episode: 1145 Step: 178000 Average reward: -122.47
# Episode: 1153 Step: 179000 Average reward: -123.71
# Episode: 1162 Step: 180000 Average reward: -121.87
# Episode: 1170 Step: 181000 Average reward: -121.21
# Episode: 1179 Step: 182000 Average reward: -120.55
# Episode: 1187 Step: 183000 Average reward: -120.01
# Episode: 1195 Step: 184000 Average reward: -120.26
# Episode: 1203 Step: 185000 Average reward: -120.5
# Episode: 1212 Step: 186000 Average reward: -121.88
# Episode: 1220 Step: 187000 Average reward: -120.68
# Episode: 1229 Step: 188000 Average reward: -119.38
# Episode: 1237 Step: 189000 Average reward: -120.16
# Episode: 1245 Step: 190000 Average reward: -120.9
# Episode: 1254 Step: 191000 Average reward: -118.51
# Episode: 1262 Step: 192000 Average reward: -120.67
# Episode: 1270 Step: 193000 Average reward: -120.44
# Episode: 1277 Step: 194000 Average reward: -122.0
# Episode: 1286 Step: 195000 Average reward: -121.94
# Episode: 1294 Step: 196000 Average reward: -121.44
# Episode: 1302 Step: 197000 Average reward: -121.39
# Episode: 1311 Step: 198000 Average reward: -120.85
# Episode: 1320 Step: 199000 Average reward: -120.6
# Episode: 1329 Step: 200000 Average reward: -120.26
# Episode: 1337 Step: 201000 Average reward: -119.66
# Episode: 1346 Step: 202000 Average reward: -118.86
# Episode: 1354 Step: 203000 Average reward: -119.65
# Episode: 1362 Step: 204000 Average reward: -119.83
# Episode: 1370 Step: 205000 Average reward: -120.92
# Episode: 1379 Step: 206000 Average reward: -118.66
# Episode: 1387 Step: 207000 Average reward: -119.15
# Episode: 1395 Step: 208000 Average reward: -118.91
# Episode: 1403 Step: 209000 Average reward: -119.06
# Episode: 1411 Step: 210000 Average reward: -120.16
# Episode: 1419 Step: 211000 Average reward: -121.04
# Episode: 1425 Step: 212000 Average reward: -123.4
# Episode: 1433 Step: 213000 Average reward: -124.55
# Episode: 1442 Step: 214000 Average reward: -124.62
# Episode: 1449 Step: 215000 Average reward: -125.2
# Episode: 1456 Step: 216000 Average reward: -127.38
# Episode: 1464 Step: 217000 Average reward: -127.36
# Episode: 1472 Step: 218000 Average reward: -128.2
# Episode: 1480 Step: 219000 Average reward: -128.49
# Episode: 1488 Step: 220000 Average reward: -128.6
# Episode: 1496 Step: 221000 Average reward: -129.05
# Episode: 1504 Step: 222000 Average reward: -128.83
# Episode: 1512 Step: 223000 Average reward: -128.8
# Episode: 1521 Step: 224000 Average reward: -126.46
# Episode: 1529 Step: 225000 Average reward: -125.87
# Episode: 1536 Step: 226000 Average reward: -126.66
# Episode: 1544 Step: 227000 Average reward: -126.5
# Episode: 1553 Step: 228000 Average reward: -124.01
# Episode: 1562 Step: 229000 Average reward: -121.9
# Episode: 1571 Step: 230000 Average reward: -121.5
# Episode: 1578 Step: 231000 Average reward: -122.19
# Episode: 1588 Step: 232000 Average reward: -119.8
# Episode: 1596 Step: 233000 Average reward: -119.0
# Episode: 1604 Step: 234000 Average reward: -120.47
# Episode: 1611 Step: 235000 Average reward: -120.34
# Episode: 1620 Step: 236000 Average reward: -121.35
# Episode: 1626 Step: 237000 Average reward: -122.01
# Episode: 1634 Step: 238000 Average reward: -122.79
# Episode: 1642 Step: 239000 Average reward: -121.59
# Episode: 1650 Step: 240000 Average reward: -122.67
# Episode: 1658 Step: 241000 Average reward: -124.41
# Episode: 1665 Step: 242000 Average reward: -126.14
# Episode: 1673 Step: 243000 Average reward: -126.59
# Episode: 1681 Step: 244000 Average reward: -127.02
# Episode: 1689 Step: 245000 Average reward: -128.45
# Episode: 1697 Step: 246000 Average reward: -129.55
# Episode: 1704 Step: 247000 Average reward: -130.05
# Episode: 1713 Step: 248000 Average reward: -127.79
# Episode: 1721 Step: 249000 Average reward: -127.69
# Episode: 1730 Step: 250000 Average reward: -125.69
# Episode: 1737 Step: 251000 Average reward: -125.72
# Episode: 1744 Step: 252000 Average reward: -126.36
# Episode: 1752 Step: 253000 Average reward: -127.91
# Episode: 1760 Step: 254000 Average reward: -127.35
# Episode: 1768 Step: 255000 Average reward: -127.02
# Episode: 1776 Step: 256000 Average reward: -126.31
# Episode: 1784 Step: 257000 Average reward: -125.17
# Episode: 1793 Step: 258000 Average reward: -125.23
# Episode: 1800 Step: 259000 Average reward: -125.07
# Episode: 1807 Step: 260000 Average reward: -126.2
# Episode: 1817 Step: 261000 Average reward: -125.59
# Episode: 1825 Step: 262000 Average reward: -125.33
# Episode: 1834 Step: 263000 Average reward: -125.22
# Episode: 1842 Step: 264000 Average reward: -123.34
# Episode: 1851 Step: 265000 Average reward: -121.92
# Episode: 1859 Step: 266000 Average reward: -121.9
# Episode: 1867 Step: 267000 Average reward: -121.74
# Episode: 1876 Step: 268000 Average reward: -120.5
# Episode: 1884 Step: 269000 Average reward: -120.29
# Episode: 1892 Step: 270000 Average reward: -121.7
# Episode: 1901 Step: 271000 Average reward: -119.07
# Episode: 1909 Step: 272000 Average reward: -118.07
# Episode: 1918 Step: 273000 Average reward: -118.09
# Episode: 1926 Step: 274000 Average reward: -119.7
# Episode: 1934 Step: 275000 Average reward: -119.65
# Episode: 1943 Step: 276000 Average reward: -119.54
# Episode: 1951 Step: 277000 Average reward: -119.76
# Episode: 1959 Step: 278000 Average reward: -119.56
# Episode: 1967 Step: 279000 Average reward: -119.89
# Episode: 1975 Step: 280000 Average reward: -120.43
# Episode: 1984 Step: 281000 Average reward: -119.77
# Episode: 1993 Step: 282000 Average reward: -118.74
# Episode: 2002 Step: 283000 Average reward: -118.69
# Episode: 2011 Step: 284000 Average reward: -118.04
# Episode: 2019 Step: 285000 Average reward: -117.94
# Episode: 2028 Step: 286000 Average reward: -117.4
# Episode: 2036 Step: 287000 Average reward: -117.36
# Episode: 2044 Step: 288000 Average reward: -117.29
# Episode: 2053 Step: 289000 Average reward: -117.33
# Episode: 2062 Step: 290000 Average reward: -116.59
# Episode: 2071 Step: 291000 Average reward: -114.61
# Episode: 2081 Step: 292000 Average reward: -113.38
# Episode: 2091 Step: 293000 Average reward: -111.73
# Episode: 2101 Step: 294000 Average reward: -111.27
# Episode: 2110 Step: 295000 Average reward: -111.29
# Episode: 2119 Step: 296000 Average reward: -110.6
# Episode: 2126 Step: 297000 Average reward: -111.42
# Episode: 2136 Step: 298000 Average reward: -110.86
# Episode: 2145 Step: 299000 Average reward: -108.75
# Episode: 2154 Step: 300000 Average reward: -109.63
# Episode: 2162 Step: 301000 Average reward: -110.7
# Episode: 2169 Step: 302000 Average reward: -111.74
# Episode: 2177 Step: 303000 Average reward: -113.76
# Episode: 2185 Step: 304000 Average reward: -116.57
# Episode: 2194 Step: 305000 Average reward: -117.41
# Episode: 2202 Step: 306000 Average reward: -118.07
# Episode: 2211 Step: 307000 Average reward: -118.59
# Episode: 2220 Step: 308000 Average reward: -118.97
# Episode: 2228 Step: 309000 Average reward: -117.04
# Episode: 2236 Step: 310000 Average reward: -118.98
# Episode: 2244 Step: 311000 Average reward: -121.21
# Episode: 2253 Step: 312000 Average reward: -120.63
# Episode: 2261 Step: 313000 Average reward: -121.62
# Episode: 2268 Step: 314000 Average reward: -122.06
# Episode: 2276 Step: 315000 Average reward: -121.95
# Episode: 2285 Step: 316000 Average reward: -120.42
# Episode: 2294 Step: 317000 Average reward: -120.22
# Episode: 2301 Step: 318000 Average reward: -120.21
# Episode: 2310 Step: 319000 Average reward: -121.28
# Episode: 2317 Step: 320000 Average reward: -122.36
# Episode: 2327 Step: 321000 Average reward: -121.91
# Episode: 2335 Step: 322000 Average reward: -122.22
# Episode: 2343 Step: 323000 Average reward: -122.18
# Episode: 2351 Step: 324000 Average reward: -122.1
# Episode: 2360 Step: 325000 Average reward: -120.77
# Episode: 2368 Step: 326000 Average reward: -118.57
# Episode: 2377 Step: 327000 Average reward: -118.35
# Episode: 2386 Step: 328000 Average reward: -117.72
# Episode: 2395 Step: 329000 Average reward: -118.27
# Episode: 2404 Step: 330000 Average reward: -116.27
# Episode: 2414 Step: 331000 Average reward: -115.28
# Episode: 2423 Step: 332000 Average reward: -113.33
# Episode: 2432 Step: 333000 Average reward: -113.88
# Episode: 2440 Step: 334000 Average reward: -113.25
# Episode: 2450 Step: 335000 Average reward: -111.04
# Episode: 2459 Step: 336000 Average reward: -111.32
# Episode: 2467 Step: 337000 Average reward: -112.08
# Episode: 2476 Step: 338000 Average reward: -111.61
# Episode: 2484 Step: 339000 Average reward: -112.47
# Episode: 2493 Step: 340000 Average reward: -112.17
# Episode: 2502 Step: 341000 Average reward: -112.85
# Episode: 2511 Step: 342000 Average reward: -113.04
# Episode: 2519 Step: 343000 Average reward: -114.81
# Episode: 2527 Step: 344000 Average reward: -115.4
# Episode: 2535 Step: 345000 Average reward: -115.81
# Episode: 2544 Step: 346000 Average reward: -116.63
# Episode: 2552 Step: 347000 Average reward: -117.6
# Episode: 2561 Step: 348000 Average reward: -118.1
# Episode: 2569 Step: 349000 Average reward: -117.57
# Episode: 2578 Step: 350000 Average reward: -117.82
# Episode: 2586 Step: 351000 Average reward: -117.64
# Episode: 2595 Step: 352000 Average reward: -117.09
# Episode: 2604 Step: 353000 Average reward: -117.87
# Episode: 2613 Step: 354000 Average reward: -117.32
# Episode: 2622 Step: 355000 Average reward: -115.45
# Episode: 2631 Step: 356000 Average reward: -115.63
# Episode: 2639 Step: 357000 Average reward: -115.91
# Episode: 2647 Step: 358000 Average reward: -115.73
# Episode: 2656 Step: 359000 Average reward: -115.69
# Episode: 2664 Step: 360000 Average reward: -115.5
# Episode: 2673 Step: 361000 Average reward: -115.48
# Episode: 2682 Step: 362000 Average reward: -114.94
# Episode: 2689 Step: 363000 Average reward: -116.34
# Episode: 2698 Step: 364000 Average reward: -116.74
# Episode: 2707 Step: 365000 Average reward: -116.37
# Episode: 2715 Step: 366000 Average reward: -117.95
# Episode: 2725 Step: 367000 Average reward: -117.11
# Episode: 2733 Step: 368000 Average reward: -116.91
# Episode: 2741 Step: 369000 Average reward: -118.05
# Episode: 2750 Step: 370000 Average reward: -116.98
# Episode: 2759 Step: 371000 Average reward: -117.13
# Episode: 2767 Step: 372000 Average reward: -117.3
# Episode: 2776 Step: 373000 Average reward: -116.99
# Episode: 2785 Step: 374000 Average reward: -115.78
# Episode: 2793 Step: 375000 Average reward: -116.1
# Episode: 2802 Step: 376000 Average reward: -116.1
# Episode: 2810 Step: 377000 Average reward: -116.28
# Episode: 2818 Step: 378000 Average reward: -117.21
# Episode: 2826 Step: 379000 Average reward: -118.11
# Episode: 2835 Step: 380000 Average reward: -117.09
# Episode: 2844 Step: 381000 Average reward: -116.39
# Episode: 2852 Step: 382000 Average reward: -117.9
# Episode: 2861 Step: 383000 Average reward: -117.42
# Episode: 2868 Step: 384000 Average reward: -118.92
# Episode: 2877 Step: 385000 Average reward: -119.33
# Episode: 2886 Step: 386000 Average reward: -117.99
# Episode: 2892 Step: 387000 Average reward: -120.92
# Episode: 2901 Step: 388000 Average reward: -121.7
# Episode: 2909 Step: 389000 Average reward: -121.27
# Episode: 2917 Step: 390000 Average reward: -120.52
# Episode: 2926 Step: 391000 Average reward: -120.15
# Episode: 2933 Step: 392000 Average reward: -122.19
# Episode: 2941 Step: 393000 Average reward: -124.27
# Episode: 2949 Step: 394000 Average reward: -123.88
# Episode: 2956 Step: 395000 Average reward: -124.86
# Episode: 2964 Step: 396000 Average reward: -125.5
# Episode: 2972 Step: 397000 Average reward: -125.65
# Episode: 2980 Step: 398000 Average reward: -125.93
# Episode: 2988 Step: 399000 Average reward: -126.2
# Episode: 2997 Step: 400000 Average reward: -125.15
# Episode: 3004 Step: 401000 Average reward: -126.36
# Episode: 3013 Step: 402000 Average reward: -125.45
# Episode: 3022 Step: 403000 Average reward: -125.25
# Episode: 3031 Step: 404000 Average reward: -123.66
# Episode: 3039 Step: 405000 Average reward: -122.55
# Episode: 3048 Step: 406000 Average reward: -121.18
# Episode: 3057 Step: 407000 Average reward: -119.64
# Episode: 3065 Step: 408000 Average reward: -118.17
# Episode: 3075 Step: 409000 Average reward: -115.97
# Episode: 3084 Step: 410000 Average reward: -114.75
# Episode: 3093 Step: 411000 Average reward: -113.63
# Episode: 3102 Step: 412000 Average reward: -112.84
# Episode: 3110 Step: 413000 Average reward: -113.52
# Episode: 3118 Step: 414000 Average reward: -113.38
# Episode: 3128 Step: 415000 Average reward: -113.7
# Episode: 3137 Step: 416000 Average reward: -112.74
# Episode: 3145 Step: 417000 Average reward: -112.98
# Episode: 3154 Step: 418000 Average reward: -112.59
# Episode: 3164 Step: 419000 Average reward: -111.7
# Episode: 3173 Step: 420000 Average reward: -112.01
# Episode: 3182 Step: 421000 Average reward: -112.39
# Episode: 3192 Step: 422000 Average reward: -112.18
# Episode: 3202 Step: 423000 Average reward: -110.08
# Episode: 3211 Step: 424000 Average reward: -108.56
# Episode: 3221 Step: 425000 Average reward: -107.54
# Episode: 3230 Step: 426000 Average reward: -107.44
# Episode: 3240 Step: 427000 Average reward: -106.48
# Episode: 3249 Step: 428000 Average reward: -105.62
# Episode: 3259 Step: 429000 Average reward: -106.03
# Episode: 3267 Step: 430000 Average reward: -106.83
# Episode: 3276 Step: 431000 Average reward: -107.2
# Episode: 3285 Step: 432000 Average reward: -106.13
# Episode: 3294 Step: 433000 Average reward: -107.35
# Episode: 3303 Step: 434000 Average reward: -108.89
# Episode: 3312 Step: 435000 Average reward: -109.16
# Episode: 3321 Step: 436000 Average reward: -109.42
# Episode: 3330 Step: 437000 Average reward: -109.76
# Episode: 3339 Step: 438000 Average reward: -110.98
# Episode: 3347 Step: 439000 Average reward: -111.29
# Episode: 3357 Step: 440000 Average reward: -111.46
# Episode: 3367 Step: 441000 Average reward: -109.33
# Episode: 3376 Step: 442000 Average reward: -109.03
# Episode: 3385 Step: 443000 Average reward: -110.08
# Episode: 3394 Step: 444000 Average reward: -109.78
# Episode: 3404 Step: 445000 Average reward: -108.76
# Episode: 3412 Step: 446000 Average reward: -110.5
# Episode: 3421 Step: 447000 Average reward: -110.52
# Episode: 3430 Step: 448000 Average reward: -110.61
# Episode: 3438 Step: 449000 Average reward: -111.12
# Episode: 3447 Step: 450000 Average reward: -111.03
# Episode: 3456 Step: 451000 Average reward: -111.41
# Episode: 3464 Step: 452000 Average reward: -113.38
# Episode: 3473 Step: 453000 Average reward: -113.59
# Episode: 3482 Step: 454000 Average reward: -114.11
# Episode: 3490 Step: 455000 Average reward: -114.14
# Episode: 3499 Step: 456000 Average reward: -114.85
# Episode: 3508 Step: 457000 Average reward: -114.08
# Episode: 3517 Step: 458000 Average reward: -114.64
# Episode: 3526 Step: 459000 Average reward: -114.6
# Episode: 3535 Step: 460000 Average reward: -113.66
# Episode: 3544 Step: 461000 Average reward: -113.47
# Episode: 3553 Step: 462000 Average reward: -113.35
# Episode: 3562 Step: 463000 Average reward: -112.89
# Episode: 3570 Step: 464000 Average reward: -112.8
# Episode: 3579 Step: 465000 Average reward: -113.14
# Episode: 3587 Step: 466000 Average reward: -113.44
# Episode: 3597 Step: 467000 Average reward: -112.36
# Episode: 3606 Step: 468000 Average reward: -111.98
# Episode: 3615 Step: 469000 Average reward: -111.9
# Episode: 3624 Step: 470000 Average reward: -111.58
# Episode: 3633 Step: 471000 Average reward: -112.7
# Episode: 3642 Step: 472000 Average reward: -112.31
# Episode: 3650 Step: 473000 Average reward: -113.48
# Episode: 3658 Step: 474000 Average reward: -113.96
# Episode: 3666 Step: 475000 Average reward: -115.15
# Episode: 3674 Step: 476000 Average reward: -115.94
# Episode: 3682 Step: 477000 Average reward: -116.38
# Episode: 3690 Step: 478000 Average reward: -117.15
# Episode: 3698 Step: 479000 Average reward: -119.41
# Episode: 3706 Step: 480000 Average reward: -120.45
# Episode: 3714 Step: 481000 Average reward: -120.45
# Episode: 3723 Step: 482000 Average reward: -121.84
# Episode: 3732 Step: 483000 Average reward: -120.87
# Episode: 3741 Step: 484000 Average reward: -120.99
# Episode: 3748 Step: 485000 Average reward: -121.72
# Episode: 3757 Step: 486000 Average reward: -121.53
# Episode: 3765 Step: 487000 Average reward: -121.21
# Episode: 3774 Step: 488000 Average reward: -120.14
# Episode: 3781 Step: 489000 Average reward: -120.25
# Episode: 3790 Step: 490000 Average reward: -120.39
# Episode: 3798 Step: 491000 Average reward: -119.99
# Episode: 3807 Step: 492000 Average reward: -118.12
# Episode: 3815 Step: 493000 Average reward: -119.11
# Episode: 3824 Step: 494000 Average reward: -118.71
# Episode: 3831 Step: 495000 Average reward: -121.1
# Episode: 3839 Step: 496000 Average reward: -121.59
# Episode: 3848 Step: 497000 Average reward: -120.2
# Episode: 3857 Step: 498000 Average reward: -120.22
# Episode: 3866 Step: 499000 Average reward: -118.99
# Episode: 3876 Step: 500000 Average reward: -118.06

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# -114.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# Những thứ thay đổi:
#
#   HyperParameter: tăng max_num_steps, tăng memory_size
#
#   Mạng neural: thêm một neural network size 128 và xài thêm mạng nn.RLU()
